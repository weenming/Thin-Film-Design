# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 20, 1000)
sinc = np.sin(x) / x
I = [sinc[:i].sum() * (x[1] - x[0]) for i in range(x.shape[0])]

fig, ax = plt.subplots(1, 1)
ax.plot(x, sinc ** 2)
ax.plot(x, 1 / x ** 2)

ax.set_ylim(0, 1)
ax.set_xlim(0, x[-1])
# Out:
# C:\Users\weenming\AppData\Local\Temp\ipykernel_33604\2819402400.py:5: RuntimeWarning: invalid value encountered in divide
#   sinc = np.sin(x) / x
# C:\Users\weenming\AppData\Local\Temp\ipykernel_33604\2819402400.py:10: RuntimeWarning: divide by zero encountered in divide
#   ax.plot(x, 1 / x ** 2)
# (0.0, 20.0)
